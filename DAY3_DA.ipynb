# %% [markdown]
# PANDAS:

# %%
import pandas as pd

# %% [markdown]
# series-index,column
# #syntax: #pd.series(column,index)

# %%
a = ["jwalitha","ramya","rupa","satya"]
r = pd.Series(a,index = [10,20,30,40])          #syntax: #pd.series(column,index)
print(r)
# Out:
# 10    jwalitha
# 20       ramya
# 30        rupa
# 40       satya
# dtype: object

# %%
a = ["jwalitha","ramya","rupa","satya"]
r = pd.Series(a)          #syntax: #pd.series(list_name)
print(r)
# Out:
# 0    jwalitha
# 1       ramya
# 2        rupa
# 3       satya
# dtype: object

# %%
col = ["blue","pink"]
ind = [33,55]
m = pd.Series(col,ind)
print(m)
# Out:
# 33    blue
# 55    pink
# dtype: object

# %%
dia =  pd.read_csv("/content/diabetcsv.csv")    #we can load csv & text files
dia
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a12b0e6a4492> in <cell line: 1>()
# ----> 1 dia =  pd.read_csv("/content/diabetcsv.csv")    #we can load csv & text files
#       2 dia
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
grad = pd.read_csv("/content/grades.txt")
grad

# %%
g = pd.read_csv("/content/grades_withnulls.txt",sep=" , ")
g

# %%
grad = pd.read_csv("/content/demodt.txt",sep=" ,")
grad

# %%
g1 = pd.read_excel("/content/diabetes.excel.xlsx")                   #excel used for excel sheets
g1

# %%
diaxl = pd.read_excel("/content/diabetes.excel.xlsx",sheet_name="dora")                   #excel used for excel sheets
diaxl

# %%
#dataframe.describe() describes each field

# %%
diaxl.describe()

# %%
grad.describe()
g.describe()
dia.describe()

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
print(df.shape)
print(df.shape[1])

# %%
df

# %%
#DATA CLEANING : DEALING WITH NULL VALUES
print(df.isnull())

# %%
print(df.isnull().sum())

# %%
df.dropna() #it dont save changes

# %%
df

# %% [markdown]
# to save changes use  inplace=True or df=dropna

# %%
df.dropna()
df

# %%
df.dropna(inplace=True)
df

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
df.dropna()
df
#to save changes  , create new dataframes or give inplace= True

# %%
df1 = pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace = True)
df1

# %%
df2 = pd.read_csv("/content/grades_withnulls.csv")
mdf=df2.dropna()
mdf

# %%
#removing ,filling
df2 = pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555)

# %%
df2 = pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True)    #saves changes
df2

# %%
df2 = pd.read_csv("/content/grades_withnulls.csv")
mv=df['SEM1'].mean()
print(mv)

# %%
df2 = pd.read_csv("/content/grades_withnulls.csv")
mv=df2['SEM1'].mean()
print(mv)
df2.fillna(mv,inplace=True)
df2
Mydf=pd.read_csv("/content/grades_withnulls.csv")
# Out:
# 8.992857142857144

# %%
Mydf = pd.read_csv("/content/grades_withnulls.csv")

# %%
#access the data
#integer locations, index
#loc =field names ,index
#dfname.loc[index]---->rows
#dfname.loc[st:stop]---->range of rows
#dfname.loc[r_ind,col_name]---->rows&col
Mydf.loc[0]   #first record
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
Mydf.loc[0:5]   #first 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
#range of records
Mydf.loc[8:14]   #8 to 14 records
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1

# %%
#Mydf.loc[5:7,"SEM1"]
Mydf.iloc[10:12,0:3]      #both rows and columns ----indexes should give
# Out:
#     Names Initials  SEM1
# 10  Kiran        V   NaN
# 11   Maya        N   7.7

# %% [markdown]
# SEARCHING DATA

# %%
Mydf[Mydf.SEM2== 9.1]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#print the records who score 9.3 in sem 3
Mydf[Mydf.SEM3 == 9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
Mydf.loc[Mydf['SEM1'] > 9.8 , ['Names']]    #index , colnames
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
#access the grades of students who score more than 9.7 in sem3
Mydf.loc[Mydf['SEM3'] > 9.7 , 'Grade']
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
#accessing using index function
print(Mydf[Mydf.index==7])#accessing only row
print("-----accessing specific row and column-------")
print(Mydf.loc[Mydf.index==7, "Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# -----accessing specific row and column-------
# 7    B
# Name: Grade, dtype: object

# %%
Mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
Mydf.drop_duplicates()    #changes not reflected
Mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
Mydf.drop_duplicates(inplace=True)    #changes reflected
Mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# for viewing inplace=False
# for viewing & saving=True

# %%
Mydf.head() # gives top 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
Mydf.tail() # gives last 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
#columns!
#Mydf.columns
colnames=Mydf.columns #view the column names
print(colnames)

# %%
#typecasting
column_list=list(Mydf.columns) #view the column names
print(column_list)

# %%
#Rename column
Mydf.rename(columns={'Grade' : 'GPA'})
Mydf.columns

# %%
Mydf.rename(columns={'Grade' : 'GPA'},inplace=True)
Mydf.columns

# %% [markdown]
# creating a neew column:
# dfname['new col']=values

# %%
Mydf["Conduct"] = "Good"
Mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed Conduct
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good
# 3     Mary        N   7.7   8.0   NaN     B       0    Good
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good
# 5      Raj        M   8.9   9.1   9.3     A       1    Good
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good
# 7     Mari        N   7.7   8.0   7.1     B       1    Good
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good
# 11    Maya        N   7.7   8.0   7.1     B       0    Good
# 12   Jolin        K   9.8   9.1   9.9    A+       1    Good
# 14    Riya        M   9.3   9.9  10.0     A       1    Good
# 15    Sana        V   9.9   9.3   9.2     A       0    Good
# ...

# %%
#create a new column average with average values of sem1,sem2,sem3

# %%
Mydf["Average"] = (Mydf['SEM1'] + Mydf['SEM2'] +Mydf['SEM3']) /3
#accessing ,renaming,creating columns are done!!!

# %%
Mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed Conduct   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...

# %% [markdown]
# PLOTTING WITH  PATTERNS:

# %%
Mydf['SEM1'].plot.line()    #dfname['col'].plot.line()
# Out:
# <Axes: >

# %%
Mydf['SEM2'].plot.line()
# Out:
# <Axes: >

# %%
#syntax: Mydefname[[' ',' ',' ',' ']].plot.line()
Mydf[['SEM1','SEM2']].plot.line()    #plotting multiple col
# Out:
# <Axes: >

# %% [markdown]
# DATA VISUALISATION USING PYTHON:

# %%
Mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
Mydf.plot.line(subplots=True)  #  all numeric columns are plotted.....
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
Mydf.plot(kind="scatter",x = "Names", y = "Average")    #kind--->attribute
# Out:
# <Axes: xlabel='Names', ylabel='Average'>

# %%
Mydf.plot(kind="hist",x = "Names", y = "Average")   #hist means histogragh which gives bargraph
# x axis - count , y axis - numeric datatype values
# Out:
# <Axes: ylabel='Frequency'>

# %%
Mydf.to_csv("Mydf.csv")   #saving a file
#syntax: dfname.to_csv("filename")
