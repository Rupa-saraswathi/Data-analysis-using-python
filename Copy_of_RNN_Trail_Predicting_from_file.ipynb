# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupa-saraswathi/Data-analysis-using-python/blob/main/Copy_of_RNN_Trail_Predicting_from_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
import pandas as pd
df = pd.read_csv("/content/earth1.txt",sep = " ,")
df
# Out:
# <ipython-input-36-1fd7076f16ec>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("/content/earth1.txt",sep = " ,")
# Empty DataFrame
# Columns: [Earth has a dynamic atmosphere, which sustains Earth's surface conditions and protects it from most meteoroids and UV-light at entry. It has a composition of primarily nitrogen and oxygen. Water vapor is widely present in the atmosphere, forming clouds that cover most of the planet. The water vapor acts as a greenhouse gas and, together with other greenhouse gases in the atmosphere, particularly carbon dioxide (CO2), creates the conditions for both liquid surface water and water vapor to persist via the capturing of energy from the Sun's light.]
# Index: []

# %%
#generating some example sequential data
sentences = ['I love learning' , 'I love python' , 'I love java' , 'I like you' , 'Recurrent Neural networks are powerful']

# %%
#tokenizing the words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df)
total_words = len(tokenizer.word_index) + 1
print(total_words)
# Out:
# 60

# %%
#creating input sentences and their corresponding next words
input_sequences = []
for sentence in df:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[17, 8],
#  [17, 8, 4],
#  [17, 8, 4, 18],
#  [17, 8, 4, 18, 5],
#  [17, 8, 4, 18, 5, 19],
#  [17, 8, 4, 18, 5, 19, 20],
#  [17, 8, 4, 18, 5, 19, 20, 21],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5,
#   34,
#   35,
#   36,
#   37,
#   13,
#   6,
#   1,
#   38,
#   1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59,
#   14]]

# %%
#padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length,padding='pre')
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0, 17,  8],
#        [ 0,  0,  0, ..., 17,  8,  4],
#        [ 0,  0,  0, ...,  8,  4, 18],
#        ...,
#        [ 0,  0, 17, ..., 58, 12,  1],
#        [ 0, 17,  8, ..., 12,  1, 59],
#        [17,  8,  4, ...,  1, 59, 14]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#training the
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 3/3 - 3s - loss: 4.2064 - accuracy: 0.0000e+00 - 3s/epoch - 834ms/step
# Epoch 2/50
# 3/3 - 0s - loss: 3.8325 - accuracy: 0.0568 - 202ms/epoch - 67ms/step
# Epoch 3/50
# 3/3 - 0s - loss: 3.6063 - accuracy: 0.2045 - 180ms/epoch - 60ms/step
# Epoch 4/50
# 3/3 - 0s - loss: 3.3997 - accuracy: 0.3864 - 163ms/epoch - 54ms/step
# Epoch 5/50
# 3/3 - 0s - loss: 3.2332 - accuracy: 0.5114 - 222ms/epoch - 74ms/step
# Epoch 6/50
# 3/3 - 0s - loss: 3.0551 - accuracy: 0.6136 - 170ms/epoch - 57ms/step
# Epoch 7/50
# 3/3 - 0s - loss: 2.8820 - accuracy: 0.6477 - 169ms/epoch - 56ms/step
# Epoch 8/50
# 3/3 - 0s - loss: 2.7270 - accuracy: 0.7159 - 175ms/epoch - 58ms/step
# Epoch 9/50
# 3/3 - 0s - loss: 2.5460 - accuracy: 0.7841 - 209ms/epoch - 70ms/step
# Epoch 10/50
# 3/3 - 0s - loss: 2.3906 - accuracy: 0.7727 - 177ms/epoch - 59ms/step
# Epoch 11/50
# 3/3 - 0s - loss: 2.2471 - accuracy: 0.8409 - 183ms/epoch - 61ms/step
# Epoch 12/50
# 3/3 - 0s - loss: 2.0769 - accuracy: 0.8864 - 183ms/epoch - 61ms/step
# Epoch 13/50
# 3/3 - 0s - loss: 1.9534 - accuracy: 0.8864 - 163ms/epoch - 54ms/step
# Epoch 14/50
# 3/3 - 0s - loss: 1.8045 - accuracy: 0.8864 - 168ms/epoch - 56ms/step
# Epoch 15/50
# 3/3 - 0s - loss: 1.6671 - accuracy: 0.9091 - 186ms/epoch - 62ms/step
# Epoch 16/50
# 3/3 - 0s - loss: 1.5322 - accuracy: 0.9205 - 194ms/epoch - 65ms/step
# Epoch 17/50
# 3/3 - 0s - loss: 1.4019 - accuracy: 0.9205 - 173ms/epoch - 58ms/step
# Epoch 18/50
# 3/3 - 0s - loss: 1.3041 - accuracy: 0.9659 - 164ms/epoch - 55ms/step
# Epoch 19/50
# 3/3 - 0s - loss: 1.1789 - accuracy: 0.9432 - 185ms/epoch - 62ms/step
# Epoch 20/50
# 3/3 - 0s - loss: 1.0852 - accuracy: 0.9432 - 290ms/epoch - 97ms/step
# Epoch 21/50
# 3/3 - 0s - loss: 0.9924 - accuracy: 0.9545 - 290ms/epoch - 97ms/step
# Epoch 22/50
# 3/3 - 0s - loss: 0.9190 - accuracy: 0.9659 - 295ms/epoch - 98ms/step
# Epoch 23/50
# 3/3 - 0s - loss: 0.8273 - accuracy: 0.9773 - 298ms/epoch - 99ms/step
# Epoch 24/50
# 3/3 - 0s - loss: 0.7591 - accuracy: 0.9773 - 294ms/epoch - 98ms/step
# Epoch 25/50
# 3/3 - 0s - loss: 0.6920 - accuracy: 0.9659 - 324ms/epoch - 108ms/step
# Epoch 26/50
# 3/3 - 0s - loss: 0.6301 - accuracy: 0.9773 - 314ms/epoch - 105ms/step
# Epoch 27/50
# 3/3 - 0s - loss: 0.5718 - accuracy: 0.9886 - 310ms/epoch - 103ms/step
# Epoch 28/50
# 3/3 - 0s - loss: 0.5236 - accuracy: 0.9773 - 297ms/epoch - 99ms/step
# Epoch 29/50
# 3/3 - 0s - loss: 0.4796 - accuracy: 0.9773 - 299ms/epoch - 100ms/step
# Epoch 30/50
# 3/3 - 0s - loss: 0.4340 - accuracy: 0.9886 - 269ms/epoch - 90ms/step
# Epoch 31/50
# 3/3 - 0s - loss: 0.4017 - accuracy: 0.9886 - 191ms/epoch - 64ms/step
# Epoch 32/50
# 3/3 - 0s - loss: 0.3699 - accuracy: 0.9886 - 196ms/epoch - 65ms/step
# Epoch 33/50
# 3/3 - 0s - loss: 0.3475 - accuracy: 0.9886 - 159ms/epoch - 53ms/step
# Epoch 34/50
# 3/3 - 0s - loss: 0.3145 - accuracy: 0.9886 - 186ms/epoch - 62ms/step
# Epoch 35/50
# 3/3 - 0s - loss: 0.2985 - accuracy: 0.9773 - 166ms/epoch - 55ms/step
# Epoch 36/50
# 3/3 - 0s - loss: 0.2781 - accuracy: 1.0000 - 176ms/epoch - 59ms/step
# Epoch 37/50
# 3/3 - 0s - loss: 0.2602 - accuracy: 0.9886 - 170ms/epoch - 57ms/step
# Epoch 38/50
# 3/3 - 0s - loss: 0.2390 - accuracy: 1.0000 - 190ms/epoch - 63ms/step
# Epoch 39/50
# 3/3 - 0s - loss: 0.2246 - accuracy: 1.0000 - 167ms/epoch - 56ms/step
# Epoch 40/50
# 3/3 - 0s - loss: 0.2141 - accuracy: 0.9886 - 159ms/epoch - 53ms/step
# Epoch 41/50
# 3/3 - 0s - loss: 0.1964 - accuracy: 1.0000 - 165ms/epoch - 55ms/step
# Epoch 42/50
# 3/3 - 0s - loss: 0.1938 - accuracy: 0.9773 - 184ms/epoch - 61ms/step
# Epoch 43/50
# 3/3 - 0s - loss: 0.1816 - accuracy: 1.0000 - 168ms/epoch - 56ms/step
# Epoch 44/50
# 3/3 - 0s - loss: 0.1731 - accuracy: 0.9886 - 171ms/epoch - 57ms/step
# Epoch 45/50
# 3/3 - 0s - loss: 0.1614 - accuracy: 0.9886 - 179ms/epoch - 60ms/step
# Epoch 46/50
# 3/3 - 0s - loss: 0.1509 - accuracy: 1.0000 - 169ms/epoch - 56ms/step
# Epoch 47/50
# 3/3 - 0s - loss: 0.1450 - accuracy: 1.0000 - 166ms/epoch - 55ms/step
# Epoch 48/50
# 3/3 - 0s - loss: 0.1385 - accuracy: 1.0000 - 166ms/epoch - 55ms/step
# Epoch 49/50
# 3/3 - 0s - loss: 0.1305 - accuracy: 1.0000 - 200ms/epoch - 67ms/step
# Epoch 50/50
# 3/3 - 0s - loss: 0.1249 - accuracy: 1.0000 - 163ms/epoch - 54ms/step

# %%
#Test:
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: earth
# Enter how many words to predict: 6
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# earth has a dynamic atmosphere which sustains
